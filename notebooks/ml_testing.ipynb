# %%
# !git clone https://github.com/shrabani3002/PERSONALIZED-TREATMENT-RECOMMENDATION-WITH-CAUSAL-MACHINE-LEARNING.git
# Out:
# Cloning into 'PERSONALIZED-TREATMENT-RECOMMENDATION-WITH-CAUSAL-MACHINE-LEARNING'...
# remote: Enumerating objects: 78, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 78 (delta 5), reused 69 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (78/78), 633.11 KiB | 9.31 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %cd PERSONALIZED-TREATMENT-RECOMMENDATION-WITH-CAUSAL-MACHINE-LEARNING
# Out:
# /content/PERSONALIZED-TREATMENT-RECOMMENDATION-WITH-CAUSAL-MACHINE-LEARNING

# %%
# !ls
# Out:
# app  config.py	migrations  ml_pipeline  README.md  requirement.txt  run.py

# %%
# !python ml_pipeline/01_explore_data.py
# Out:
# Traceback (most recent call last):
#   File "/content/PERSONALIZED-TREATMENT-RECOMMENDATION-WITH-CAUSAL-MACHINE-LEARNING/ml_pipeline/01_explore_data.py", line 13, in <module>
#     df = pd.read_csv(DATA_PATH)
#          ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 620, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1620, in __init__
#     self._engine = self._make_engine(f, self.engine)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1880, in _make_engine
# ...
